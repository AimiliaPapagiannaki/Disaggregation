# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import changefinder
import ruptures as rpt
# %matplotlib inline

# %%
df = pd.read_csv('watt_analytics_data.csv')
df['ts'] = pd.to_datetime(df['ts'], unit='ms',utc=True)
df.set_index('ts',inplace=True, drop=True)
df.head()
# Out:
#                                      pwrA    pwrB    pwrC   rpwrA    rpwrB  \
# ts
# 2022-02-17 12:29:03.320000+00:00  168.586  37.383  35.605  27.808 -102.561
# 2022-02-17 12:29:03.570000+00:00  168.632  37.519  36.106  24.366 -102.372
# 2022-02-17 12:29:03.820000+00:00  171.048  37.337  36.334  27.327 -102.516
# 2022-02-17 12:29:04.070000+00:00  171.094  37.383  36.015  28.913 -101.430
# 2022-02-17 12:29:04.320000+00:00  174.330  37.383  35.878  25.974 -101.456
#
#                                     rpwrC
# ts
# 2022-02-17 12:29:03.320000+00:00 -101.412
# 2022-02-17 12:29:03.570000+00:00 -100.125
# 2022-02-17 12:29:03.820000+00:00 -101.429
# 2022-02-17 12:29:04.070000+00:00 -101.070
# 2022-02-17 12:29:04.320000+00:00 -101.579

# %%
dfA = df[['pwrA','rpwrA']].iloc[:10000].copy()
# dfA = dfA.resample('1S').mean()
dfA['pwrA'].plot()
dfA['rpwrA'].plot()
# Out:
# <AxesSubplot:xlabel='ts'>

# %%
# fig = plt.figure(figsize=[10,8])
# plt.scatter(dfA['pwrA'],dfA['rpwrA'])

# %%
ts1 = dfA['pwrA'].to_numpy()

# %%
# Detect the change points
algo1 = rpt.Pelt(model="rbf").fit(ts1)
change_location1 = algo1.predict(pen=10)

# Point the change points:
def plot_change_points(ts,ts_change_loc):
    plt.figure(figsize=(16,4))
    plt.plot(ts)
    for x in ts_change_loc:
        plt.axvline(x,lw=2, color='red')

plot_change_points(ts1,change_location1)

# %%
def findChangePoints(ts, r, order, smooth):
    
    cf = changefinder.ChangeFinder(r=r, order=order, smooth=smooth)
    ts_score = [cf.update(p) for p in ts]
    plt.figure(figsize=(16,4))
    plt.plot(ts)
    plt.figure(figsize=(16,4))
    plt.plot(ts_score, color='red')
    return(ts_score)
    
ts_score1 = findChangePoints(ts1, r = 0.1, order = 3, smooth = 8)

# %%
ts_change_loc1 = pd.Series(ts_score1).nlargest(100)
ts_change_loc1 = ts_change_loc1.index
ts_change_loc1
# Out:
# Int64Index([  25,   24,   41,   42,   27,   40,   16,   43,   26,   18,   39,
#               44,   23,   38,   45,   22,   17,   28,   29,   37,   30,   46,
#               47,   36,   31,   48,   32,   35,   33,   34,   49,   50,   51,
#               52,   53,   54,   55,   56,   19,   57,   58,   59,   60,   20,
#               61,   62,   63,   21,   64,   65,   66,   67,   68,   69,   70,
#               71,   72,   73,   74,   75,   76,   77,   78,   79,   80,   81,
#              247,   82,   83,  185,   84, 1988, 1099, 1098,   85,   86,   87,
#              942,   88, 1672, 1753, 1510,   89, 1511, 1108,  248, 1916,  485,
#               90, 1509, 1990,   91, 1100, 1109,  257,   92, 1107,  256, 1833,
#             1258],
#            dtype='int64')

# %%
def plot_change_points(ts,ts_change_loc):
    plt.figure(figsize=(16,4))
    plt.plot(ts)
    for x in ts_change_loc:
        plt.axvline(x,lw=2, color='red')
        
plot_change_points(ts1,ts_change_loc1)
