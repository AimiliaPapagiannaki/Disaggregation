// %%
// #include <stdio.h>
// #include <stdlib.h>
// #define size 40 //equivalent to 2 windows of 20 samples each

// float buf[size]; //initialize buffer
// float steady[(size/2)*5]; //initialize a second buffer to store 5 windows worth of data
// int headIndex = 0; //keeps track of the 1st element's position
// int thres = 40; //define threshold in watts
// int flag=0; // if flag==0 event detection is ongoing. If flag==1 a 2nd buffer is filled with next 100 samples
// int i=0; //number of elements in steady
// int counter=0; // number of elements in buf

// int rollbuf(float tail)
// {
//     buf[headIndex] = tail; //new entry is stored at headIndex position
//     headIndex = (headIndex + 1) % size; 
//     counter++;
//     return 0;
// }


// void simul(float raw)
// {
//     if (flag==0)
//     {
        
//         float s1 = 0.0, s2 = 0.0, avg1,avg2;
        
//         rollbuf(raw);
//         if (counter >= size) //if buffer is full, calculate averages
//         {
//             int j;
//             for (j=headIndex;j<(size/2)+headIndex;j++)
//             {
//                 s1 += buf[j%size]; //compute sum of 1st window
//                 s2 += buf[(j%size+(size/2))%size]; //compute sum of 2nd window
//             }
            
//             //compute corresponding averages
//             avg1 = s1/(size/2); 
//             avg2 = s2/(size/2);

//             if ((avg1-avg2)>thres || (avg2-avg1)>thres) //event detected
//             {
//                 //printf("Event detected \n");
//                 flag=1;
//                 i=0;
//             } 
//         }
//     }
    
//     else
//     {
//         // if steady buffer is not full, keep storing samples
//         if (i < (sizeof(steady) / sizeof(float))) 
//         {
//             //Store next 5 windows' samples
//             steady[i] = raw;
//             i++;
//         }
//         else
//         {
//             // send data of both buffers to the cloud 
//             flag=0;
//             i=0;
//             counter=0;
            
//         }
//     }

// }
    
// int random_stream(int max_reps)
// {
//     float x = 0;
//     for (int n=0; n<max_reps;n++)
//     {
//         x = rand();
//         simul(x);
//     }
//     return 0;
// }

// int main(int argc, char **argv) {    
    
//     int y;
//     y = random_stream(1000);
    
//     return 0;
// }

// %%
#include <stdio.h>
#include <stdlib.h>


#define SIZE 40 //equivalent to 2 windows of 20 samples each
#define HALF_SIZE ( SIZE / 2 )
#define ROLLED(IDX) ( (IDX < HALF_SIZE ? SIZE : 0) + IDX - HALF_SIZE )
#define CURR 1  // Index of current sum/average
#define PREV 0  // Index Previous sum/average
#define STEADY_SIZE (HALF_SIZE * 5)
#define MAX_REPS 1000
#define RANGE 1000
#define THRES 40.0  //define threshold in watts

#define MIN(A, B) ( A < B ? A : B )
#define ABS(X) ( X < 0 ? -X : X )



void clear_buff(float buf[])
    /* clear the buffer */
{
    for(int i=0; i<SIZE; i++) {
        buf[i] = 0.0;
    }
}
    

void eventoring(float raw, float buf[], float steady[])
/* Monitor events by checking rolling averages of streaming input*/
{
    static float sums[2] = { 0, 0 };
    float avgs[2] = { 0, 0 };
    float rolled;
    // if flag==0 event detection is ongoing. If flag==1 a 2nd buffer is filled with next 100 samples
    static unsigned int scount=0, flag=0, counter=0;   
    unsigned int index;
    

    index = counter++ % SIZE;

    if (!flag)    
    {
        /* gradually calculate averages*/
        rolled = buf[ROLLED(index)]; 
    
        /* add the new value, remove the replaced one */
        sums[CURR] += raw - rolled;
        sums[PREV] += rolled - buf[index]; 
        printf("%5u. buf[%u] was %.3f, becoming %.3f, rolled is buf[%u] = %.3f.\n", counter, index, buf[index], raw, ROLLED(index), rolled);
        
        buf[index] = raw;
        printf("%5u. Input is %.3f. Current sums are %.3f // %.3f. \n", counter, raw, sums[0], sums[1]);
        
        /*Check if buffer is full and modulo 20 == 0*/
        if ((counter >= SIZE)&&(!(counter%20)))
        {
            printf("checking averages...\n");
            for (int j=0; j<2; j++) {
                avgs[j] = sums[j] / HALF_SIZE;
            }
            
            if (ABS(avgs[0]-avgs[1]) > THRES) 
            {
                printf("Event detected. Averages differ by %.3f \n", avgs[0]-avgs[1]);
                flag=1;
            }
        }

        
    } else {
        // if steady buffer is not full, keep storing samples
        if (scount < STEADY_SIZE) 
        {
            //Store next 5 windows' samples
            steady[scount++] = raw;
        }
        else
        {
            // TODO: send data of both buffers to the cloud 
            flag=0; scount=0; counter=0;
            clear_buff(buf);
        }
    }

}




int main(int argc, char **argv)
{    
    unsigned int reps = MAX_REPS;
    float buf[SIZE]; // initialize buffer
    float steady[STEADY_SIZE]; //initialize a second buffer to store 5 windows worth of data
    
    clear_buff(buf);

    if (argc > 1) {
        reps = atoi(argv[1]);
    }

    int k;
    for(int j=0; j<reps; j++) {
        eventoring(rand() % RANGE, buf, steady);
    }
    
    return 0;
}
// Out:
//     1. buf[0] was 0.000, becoming 0.000, rolled is buf[20] = 0.000.
//     1. Input is 0.000. Current sums are 0.000 // 0.000.
//     2. buf[1] was 0.000, becoming 1.000, rolled is buf[21] = 0.000.
//     2. Input is 1.000. Current sums are 0.000 // 1.000.
//     3. buf[2] was 0.000, becoming 2.000, rolled is buf[22] = 0.000.
//     3. Input is 2.000. Current sums are 0.000 // 3.000.
//     4. buf[3] was 0.000, becoming 3.000, rolled is buf[23] = 0.000.
//     4. Input is 3.000. Current sums are 0.000 // 6.000.
//     5. buf[4] was 0.000, becoming 4.000, rolled is buf[24] = 0.000.
//     5. Input is 4.000. Current sums are 0.000 // 10.000.
//     6. buf[5] was 0.000, becoming 5.000, rolled is buf[25] = 0.000.
//     6. Input is 5.000. Current sums are 0.000 // 15.000.
//     7. buf[6] was 0.000, becoming 6.000, rolled is buf[26] = 0.000.
//     7. Input is 6.000. Current sums are 0.000 // 21.000.
//     8. buf[7] was 0.000, becoming 7.000, rolled is buf[27] = 0.000.
//     8. Input is 7.000. Current sums are 0.000 // 28.000.
//     9. buf[8] was 0.000, becoming 8.000, rolled is buf[28] = 0.000.
//     9. Input is 8.000. Current sums are 0.000 // 36.000.
//    10. buf[9] was 0.000, becoming 9.000, rolled is buf[29] = 0.000.
//    10. Input is 9.000. Current sums are 0.000 // 45.000.
//    11. buf[10] was 0.000, becoming 10.000, rolled is buf[30] = 0.000.
//    11. Input is 10.000. Current sums are 0.000 // 55.000.
//    12. buf[11] was 0.000, becoming 11.000, rolled is buf[31] = 0.000.
//    12. Input is 11.000. Current sums are 0.000 // 66.000.
//    13. buf[12] was 0.000, becoming 12.000, rolled is buf[32] = 0.000.
//    13. Input is 12.000. Current sums are 0.000 // 78.000.
//    14. buf[13] was 0.000, becoming 13.000, rolled is buf[33] = 0.000.
//    14. Input is 13.000. Current sums are 0.000 // 91.000.
//    15. buf[14] was 0.000, becoming 14.000, rolled is buf[34] = 0.000.
//    15. Input is 14.000. Current sums are 0.000 // 105.000.
//    16. buf[15] was 0.000, becoming 15.000, rolled is buf[35] = 0.000.
//    16. Input is 15.000. Current sums are 0.000 // 120.000.
//    17. buf[16] was 0.000, becoming 16.000, rolled is buf[36] = 0.000.
//    17. Input is 16.000. Current sums are 0.000 // 136.000.
//    18. buf[17] was 0.000, becoming 17.000, rolled is buf[37] = 0.000.
//    18. Input is 17.000. Current sums are 0.000 // 153.000.
//    19. buf[18] was 0.000, becoming 18.000, rolled is buf[38] = 0.000.
//    19. Input is 18.000. Current sums are 0.000 // 171.000.
//    20. buf[19] was 0.000, becoming 19.000, rolled is buf[39] = 0.000.
//    20. Input is 19.000. Current sums are 0.000 // 190.000.
//    21. buf[20] was 0.000, becoming 20.000, rolled is buf[0] = 0.000.
//    21. Input is 20.000. Current sums are 0.000 // 210.000.
//    22. buf[21] was 0.000, becoming 21.000, rolled is buf[1] = 1.000.
//    22. Input is 21.000. Current sums are 1.000 // 230.000.
//    23. buf[22] was 0.000, becoming 22.000, rolled is buf[2] = 2.000.
//    23. Input is 22.000. Current sums are 3.000 // 250.000.
//    24. buf[23] was 0.000, becoming 23.000, rolled is buf[3] = 3.000.
//    24. Input is 23.000. Current sums are 6.000 // 270.000.
//    25. buf[24] was 0.000, becoming 24.000, rolled is buf[4] = 4.000.
//    25. Input is 24.000. Current sums are 10.000 // 290.000.
//    26. buf[25] was 0.000, becoming 25.000, rolled is buf[5] = 5.000.
//    26. Input is 25.000. Current sums are 15.000 // 310.000.
//    27. buf[26] was 0.000, becoming 26.000, rolled is buf[6] = 6.000.
//    27. Input is 26.000. Current sums are 21.000 // 330.000.
//    28. buf[27] was 0.000, becoming 27.000, rolled is buf[7] = 7.000.
//    28. Input is 27.000. Current sums are 28.000 // 350.000.
//    29. buf[28] was 0.000, becoming 28.000, rolled is buf[8] = 8.000.
//    29. Input is 28.000. Current sums are 36.000 // 370.000.
//    30. buf[29] was 0.000, becoming 29.000, rolled is buf[9] = 9.000.
//    30. Input is 29.000. Current sums are 45.000 // 390.000.
//    31. buf[30] was 0.000, becoming 30.000, rolled is buf[10] = 10.000.
//    31. Input is 30.000. Current sums are 55.000 // 410.000.
//    32. buf[31] was 0.000, becoming 31.000, rolled is buf[11] = 11.000.
//    32. Input is 31.000. Current sums are 66.000 // 430.000.
//    33. buf[32] was 0.000, becoming 32.000, rolled is buf[12] = 12.000.
//    33. Input is 32.000. Current sums are 78.000 // 450.000.
//    34. buf[33] was 0.000, becoming 33.000, rolled is buf[13] = 13.000.
//    34. Input is 33.000. Current sums are 91.000 // 470.000.
//    35. buf[34] was 0.000, becoming 34.000, rolled is buf[14] = 14.000.
//    35. Input is 34.000. Current sums are 105.000 // 490.000.
//    36. buf[35] was 0.000, becoming 35.000, rolled is buf[15] = 15.000.
//    36. Input is 35.000. Current sums are 120.000 // 510.000.
//    37. buf[36] was 0.000, becoming 36.000, rolled is buf[16] = 16.000.
//    37. Input is 36.000. Current sums are 136.000 // 530.000.
//    38. buf[37] was 0.000, becoming 37.000, rolled is buf[17] = 17.000.
//    38. Input is 37.000. Current sums are 153.000 // 550.000.
//    39. buf[38] was 0.000, becoming 38.000, rolled is buf[18] = 18.000.
//    39. Input is 38.000. Current sums are 171.000 // 570.000.
//    40. buf[39] was 0.000, becoming 39.000, rolled is buf[19] = 19.000.
//    40. Input is 39.000. Current sums are 190.000 // 590.000.
// checking averages...
//    41. buf[0] was 0.000, becoming 40.000, rolled is buf[20] = 20.000.
//    41. Input is 40.000. Current sums are 210.000 // 610.000.
//    42. buf[1] was 1.000, becoming 41.000, rolled is buf[21] = 21.000.
//    42. Input is 41.000. Current sums are 230.000 // 630.000.
//    43. buf[2] was 2.000, becoming 42.000, rolled is buf[22] = 22.000.
//    43. Input is 42.000. Current sums are 250.000 // 650.000.
//    44. buf[3] was 3.000, becoming 43.000, rolled is buf[23] = 23.000.
//    44. Input is 43.000. Current sums are 270.000 // 670.000.
//    45. buf[4] was 4.000, becoming 44.000, rolled is buf[24] = 24.000.
//    45. Input is 44.000. Current sums are 290.000 // 690.000.
//    46. buf[5] was 5.000, becoming 45.000, rolled is buf[25] = 25.000.
//    46. Input is 45.000. Current sums are 310.000 // 710.000.
//    47. buf[6] was 6.000, becoming 46.000, rolled is buf[26] = 26.000.
//    47. Input is 46.000. Current sums are 330.000 // 730.000.
//    48. buf[7] was 7.000, becoming 47.000, rolled is buf[27] = 27.000.
//    48. Input is 47.000. Current sums are 350.000 // 750.000.
//    49. buf[8] was 8.000, becoming 48.000, rolled is buf[28] = 28.000.
//    49. Input is 48.000. Current sums are 370.000 // 770.000.
//    50. buf[9] was 9.000, becoming 49.000, rolled is buf[29] = 29.000.
//    50. Input is 49.000. Current sums are 390.000 // 790.000.
//    51. buf[10] was 10.000, becoming 50.000, rolled is buf[30] = 30.000.
//    51. Input is 50.000. Current sums are 410.000 // 810.000.
//    52. buf[11] was 11.000, becoming 51.000, rolled is buf[31] = 31.000.
//    52. Input is 51.000. Current sums are 430.000 // 830.000.
//    53. buf[12] was 12.000, becoming 52.000, rolled is buf[32] = 32.000.
//    53. Input is 52.000. Current sums are 450.000 // 850.000.
//    54. buf[13] was 13.000, becoming 53.000, rolled is buf[33] = 33.000.
//    54. Input is 53.000. Current sums are 470.000 // 870.000.
//    55. buf[14] was 14.000, becoming 54.000, rolled is buf[34] = 34.000.
//    55. Input is 54.000. Current sums are 490.000 // 890.000.
//    56. buf[15] was 15.000, becoming 55.000, rolled is buf[35] = 35.000.
//    56. Input is 55.000. Current sums are 510.000 // 910.000.
//    57. buf[16] was 16.000, becoming 56.000, rolled is buf[36] = 36.000.
//    57. Input is 56.000. Current sums are 530.000 // 930.000.
//    58. buf[17] was 17.000, becoming 57.000, rolled is buf[37] = 37.000.
//    58. Input is 57.000. Current sums are 550.000 // 950.000.
//    59. buf[18] was 18.000, becoming 58.000, rolled is buf[38] = 38.000.
//    59. Input is 58.000. Current sums are 570.000 // 970.000.
//    60. buf[19] was 19.000, becoming 59.000, rolled is buf[39] = 39.000.
//    60. Input is 59.000. Current sums are 590.000 // 990.000.
// checking averages...
//    61. buf[20] was 20.000, becoming 60.000, rolled is buf[0] = 40.000.
//    61. Input is 60.000. Current sums are 610.000 // 1010.000.
//    62. buf[21] was 21.000, becoming 61.000, rolled is buf[1] = 41.000.
//    62. Input is 61.000. Current sums are 630.000 // 1030.000.
//    63. buf[22] was 22.000, becoming 62.000, rolled is buf[2] = 42.000.
//    63. Input is 62.000. Current sums are 650.000 // 1050.000.
//    64. buf[23] was 23.000, becoming 63.000, rolled is buf[3] = 43.000.
//    64. Input is 63.000. Current sums are 670.000 // 1070.000.
//    65. buf[24] was 24.000, becoming 64.000, rolled is buf[4] = 44.000.
//    65. Input is 64.000. Current sums are 690.000 // 1090.000.
//    66. buf[25] was 25.000, becoming 65.000, rolled is buf[5] = 45.000.
//    66. Input is 65.000. Current sums are 710.000 // 1110.000.
//    67. buf[26] was 26.000, becoming 66.000, rolled is buf[6] = 46.000.
//    67. Input is 66.000. Current sums are 730.000 // 1130.000.
//    68. buf[27] was 27.000, becoming 67.000, rolled is buf[7] = 47.000.
//    68. Input is 67.000. Current sums are 750.000 // 1150.000.
//    69. buf[28] was 28.000, becoming 68.000, rolled is buf[8] = 48.000.
//    69. Input is 68.000. Current sums are 770.000 // 1170.000.
//    70. buf[29] was 29.000, becoming 69.000, rolled is buf[9] = 49.000.
//    70. Input is 69.000. Current sums are 790.000 // 1190.000.
//    71. buf[30] was 30.000, becoming 70.000, rolled is buf[10] = 50.000.
//    71. Input is 70.000. Current sums are 810.000 // 1210.000.
//    72. buf[31] was 31.000, becoming 71.000, rolled is buf[11] = 51.000.
//    72. Input is 71.000. Current sums are 830.000 // 1230.000.
//    73. buf[32] was 32.000, becoming 72.000, rolled is buf[12] = 52.000.
//    73. Input is 72.000. Current sums are 850.000 // 1250.000.
//    74. buf[33] was 33.000, becoming 73.000, rolled is buf[13] = 53.000.
//    74. Input is 73.000. Current sums are 870.000 // 1270.000.
//    75. buf[34] was 34.000, becoming 74.000, rolled is buf[14] = 54.000.
//    75. Input is 74.000. Current sums are 890.000 // 1290.000.
//    76. buf[35] was 35.000, becoming 75.000, rolled is buf[15] = 55.000.
//    76. Input is 75.000. Current sums are 910.000 // 1310.000.
//    77. buf[36] was 36.000, becoming 76.000, rolled is buf[16] = 56.000.
//    77. Input is 76.000. Current sums are 930.000 // 1330.000.
//    78. buf[37] was 37.000, becoming 77.000, rolled is buf[17] = 57.000.
//    78. Input is 77.000. Current sums are 950.000 // 1350.000.
//    79. buf[38] was 38.000, becoming 78.000, rolled is buf[18] = 58.000.
//    79. Input is 78.000. Current sums are 970.000 // 1370.000.
//    80. buf[39] was 39.000, becoming 79.000, rolled is buf[19] = 59.000.
//    80. Input is 79.000. Current sums are 990.000 // 1390.000.
// checking averages...
//    81. buf[0] was 40.000, becoming 80.000, rolled is buf[20] = 60.000.
//    81. Input is 80.000. Current sums are 1010.000 // 1410.000.
//    82. buf[1] was 41.000, becoming 81.000, rolled is buf[21] = 61.000.
//    82. Input is 81.000. Current sums are 1030.000 // 1430.000.
//    83. buf[2] was 42.000, becoming 82.000, rolled is buf[22] = 62.000.
//    83. Input is 82.000. Current sums are 1050.000 // 1450.000.
//    84. buf[3] was 43.000, becoming 83.000, rolled is buf[23] = 63.000.
//    84. Input is 83.000. Current sums are 1070.000 // 1470.000.
//    85. buf[4] was 44.000, becoming 84.000, rolled is buf[24] = 64.000.
//    85. Input is 84.000. Current sums are 1090.000 // 1490.000.
//    86. buf[5] was 45.000, becoming 85.000, rolled is buf[25] = 65.000.
//    86. Input is 85.000. Current sums are 1110.000 // 1510.000.
//    87. buf[6] was 46.000, becoming 86.000, rolled is buf[26] = 66.000.
//    87. Input is 86.000. Current sums are 1130.000 // 1530.000.
//    88. buf[7] was 47.000, becoming 87.000, rolled is buf[27] = 67.000.
//    88. Input is 87.000. Current sums are 1150.000 // 1550.000.
//    89. buf[8] was 48.000, becoming 88.000, rolled is buf[28] = 68.000.
//    89. Input is 88.000. Current sums are 1170.000 // 1570.000.
//    90. buf[9] was 49.000, becoming 89.000, rolled is buf[29] = 69.000.
//    90. Input is 89.000. Current sums are 1190.000 // 1590.000.
//    91. buf[10] was 50.000, becoming 90.000, rolled is buf[30] = 70.000.
//    91. Input is 90.000. Current sums are 1210.000 // 1610.000.
//    92. buf[11] was 51.000, becoming 91.000, rolled is buf[31] = 71.000.
//    92. Input is 91.000. Current sums are 1230.000 // 1630.000.
//    93. buf[12] was 52.000, becoming 92.000, rolled is buf[32] = 72.000.
//    93. Input is 92.000. Current sums are 1250.000 // 1650.000.
//    94. buf[13] was 53.000, becoming 93.000, rolled is buf[33] = 73.000.
//    94. Input is 93.000. Current sums are 1270.000 // 1670.000.
//    95. buf[14] was 54.000, becoming 94.000, rolled is buf[34] = 74.000.
//    95. Input is 94.000. Current sums are 1290.000 // 1690.000.
//    96. buf[15] was 55.000, becoming 95.000, rolled is buf[35] = 75.000.
//    96. Input is 95.000. Current sums are 1310.000 // 1710.000.
//    97. buf[16] was 56.000, becoming 96.000, rolled is buf[36] = 76.000.
//    97. Input is 96.000. Current sums are 1330.000 // 1730.000.
//    98. buf[17] was 57.000, becoming 97.000, rolled is buf[37] = 77.000.
//    98. Input is 97.000. Current sums are 1350.000 // 1750.000.
//    99. buf[18] was 58.000, becoming 98.000, rolled is buf[38] = 78.000.
//    99. Input is 98.000. Current sums are 1370.000 // 1770.000.
//   100. buf[19] was 59.000, becoming 99.000, rolled is buf[39] = 79.000.
//   100. Input is 99.000. Current sums are 1390.000 // 1790.000.
// checking averages...
//   101. buf[20] was 60.000, becoming 100.000, rolled is buf[0] = 80.000.
//   101. Input is 100.000. Current sums are 1410.000 // 1810.000.
//   102. buf[21] was 61.000, becoming 101.000, rolled is buf[1] = 81.000.
//   102. Input is 101.000. Current sums are 1430.000 // 1830.000.
//   103. buf[22] was 62.000, becoming 102.000, rolled is buf[2] = 82.000.
//   103. Input is 102.000. Current sums are 1450.000 // 1850.000.
//   104. buf[23] was 63.000, becoming 103.000, rolled is buf[3] = 83.000.
//   104. Input is 103.000. Current sums are 1470.000 // 1870.000.
//   105. buf[24] was 64.000, becoming 104.000, rolled is buf[4] = 84.000.
//   105. Input is 104.000. Current sums are 1490.000 // 1890.000.
//   106. buf[25] was 65.000, becoming 105.000, rolled is buf[5] = 85.000.
//   106. Input is 105.000. Current sums are 1510.000 // 1910.000.
//   107. buf[26] was 66.000, becoming 106.000, rolled is buf[6] = 86.000.
//   107. Input is 106.000. Current sums are 1530.000 // 1930.000.
//   108. buf[27] was 67.000, becoming 107.000, rolled is buf[7] = 87.000.
//   108. Input is 107.000. Current sums are 1550.000 // 1950.000.
//   109. buf[28] was 68.000, becoming 108.000, rolled is buf[8] = 88.000.
//   109. Input is 108.000. Current sums are 1570.000 // 1970.000.
//   110. buf[29] was 69.000, becoming 109.000, rolled is buf[9] = 89.000.
//   110. Input is 109.000. Current sums are 1590.000 // 1990.000.
//   111. buf[30] was 70.000, becoming 110.000, rolled is buf[10] = 90.000.
//   111. Input is 110.000. Current sums are 1610.000 // 2010.000.
//   112. buf[31] was 71.000, becoming 111.000, rolled is buf[11] = 91.000.
//   112. Input is 111.000. Current sums are 1630.000 // 2030.000.
//   113. buf[32] was 72.000, becoming 112.000, rolled is buf[12] = 92.000.
//   113. Input is 112.000. Current sums are 1650.000 // 2050.000.
//   114. buf[33] was 73.000, becoming 113.000, rolled is buf[13] = 93.000.
//   114. Input is 113.000. Current sums are 1670.000 // 2070.000.
//   115. buf[34] was 74.000, becoming 114.000, rolled is buf[14] = 94.000.
//   115. Input is 114.000. Current sums are 1690.000 // 2090.000.
//   116. buf[35] was 75.000, becoming 115.000, rolled is buf[15] = 95.000.
//   116. Input is 115.000. Current sums are 1710.000 // 2110.000.
//   117. buf[36] was 76.000, becoming 116.000, rolled is buf[16] = 96.000.
//   117. Input is 116.000. Current sums are 1730.000 // 2130.000.
//   118. buf[37] was 77.000, becoming 117.000, rolled is buf[17] = 97.000.
//   118. Input is 117.000. Current sums are 1750.000 // 2150.000.
//   119. buf[38] was 78.000, becoming 118.000, rolled is buf[18] = 98.000.
//   119. Input is 118.000. Current sums are 1770.000 // 2170.000.
//   120. buf[39] was 79.000, becoming 119.000, rolled is buf[19] = 99.000.
//   120. Input is 119.000. Current sums are 1790.000 // 2190.000.
// checking averages...
//   121. buf[0] was 80.000, becoming 120.000, rolled is buf[20] = 100.000.
//   121. Input is 120.000. Current sums are 1810.000 // 2210.000.
//   122. buf[1] was 81.000, becoming 121.000, rolled is buf[21] = 101.000.
//   122. Input is 121.000. Current sums are 1830.000 // 2230.000.
//   123. buf[2] was 82.000, becoming 122.000, rolled is buf[22] = 102.000.
//   123. Input is 122.000. Current sums are 1850.000 // 2250.000.
//   124. buf[3] was 83.000, becoming 123.000, rolled is buf[23] = 103.000.
//   124. Input is 123.000. Current sums are 1870.000 // 2270.000.
//   125. buf[4] was 84.000, becoming 124.000, rolled is buf[24] = 104.000.
//   125. Input is 124.000. Current sums are 1890.000 // 2290.000.
//   126. buf[5] was 85.000, becoming 125.000, rolled is buf[25] = 105.000.
//   126. Input is 125.000. Current sums are 1910.000 // 2310.000.
//   127. buf[6] was 86.000, becoming 126.000, rolled is buf[26] = 106.000.
//   127. Input is 126.000. Current sums are 1930.000 // 2330.000.
//   128. buf[7] was 87.000, becoming 127.000, rolled is buf[27] = 107.000.
//   128. Input is 127.000. Current sums are 1950.000 // 2350.000.
//   129. buf[8] was 88.000, becoming 128.000, rolled is buf[28] = 108.000.
//   129. Input is 128.000. Current sums are 1970.000 // 2370.000.
//   130. buf[9] was 89.000, becoming 129.000, rolled is buf[29] = 109.000.
//   130. Input is 129.000. Current sums are 1990.000 // 2390.000.
//   131. buf[10] was 90.000, becoming 130.000, rolled is buf[30] = 110.000.
//   131. Input is 130.000. Current sums are 2010.000 // 2410.000.
//   132. buf[11] was 91.000, becoming 131.000, rolled is buf[31] = 111.000.
//   132. Input is 131.000. Current sums are 2030.000 // 2430.000.
//   133. buf[12] was 92.000, becoming 132.000, rolled is buf[32] = 112.000.
//   133. Input is 132.000. Current sums are 2050.000 // 2450.000.
//   134. buf[13] was 93.000, becoming 133.000, rolled is buf[33] = 113.000.
//   134. Input is 133.000. Current sums are 2070.000 // 2470.000.
//   135. buf[14] was 94.000, becoming 134.000, rolled is buf[34] = 114.000.
//   135. Input is 134.000. Current sums are 2090.000 // 2490.000.
//   136. buf[15] was 95.000, becoming 135.000, rolled is buf[35] = 115.000.
//   136. Input is 135.000. Current sums are 2110.000 // 2510.000.
//   137. buf[16] was 96.000, becoming 136.000, rolled is buf[36] = 116.000.
//   137. Input is 136.000. Current sums are 2130.000 // 2530.000.
//   138. buf[17] was 97.000, becoming 137.000, rolled is buf[37] = 117.000.
//   138. Input is 137.000. Current sums are 2150.000 // 2550.000.
//   139. buf[18] was 98.000, becoming 138.000, rolled is buf[38] = 118.000.
//   139. Input is 138.000. Current sums are 2170.000 // 2570.000.
//   140. buf[19] was 99.000, becoming 139.000, rolled is buf[39] = 119.000.
//   140. Input is 139.000. Current sums are 2190.000 // 2590.000.
// checking averages...
//   141. buf[20] was 100.000, becoming 140.000, rolled is buf[0] = 120.000.
//   141. Input is 140.000. Current sums are 2210.000 // 2610.000.
//   142. buf[21] was 101.000, becoming 141.000, rolled is buf[1] = 121.000.
//   142. Input is 141.000. Current sums are 2230.000 // 2630.000.
//   143. buf[22] was 102.000, becoming 142.000, rolled is buf[2] = 122.000.
//   143. Input is 142.000. Current sums are 2250.000 // 2650.000.
//   144. buf[23] was 103.000, becoming 143.000, rolled is buf[3] = 123.000.
//   144. Input is 143.000. Current sums are 2270.000 // 2670.000.
//   145. buf[24] was 104.000, becoming 144.000, rolled is buf[4] = 124.000.
//   145. Input is 144.000. Current sums are 2290.000 // 2690.000.
//   146. buf[25] was 105.000, becoming 145.000, rolled is buf[5] = 125.000.
//   146. Input is 145.000. Current sums are 2310.000 // 2710.000.
//   147. buf[26] was 106.000, becoming 146.000, rolled is buf[6] = 126.000.
//   147. Input is 146.000. Current sums are 2330.000 // 2730.000.
//   148. buf[27] was 107.000, becoming 147.000, rolled is buf[7] = 127.000.
//   148. Input is 147.000. Current sums are 2350.000 // 2750.000.
//   149. buf[28] was 108.000, becoming 148.000, rolled is buf[8] = 128.000.
//   149. Input is 148.000. Current sums are 2370.000 // 2770.000.
//   150. buf[29] was 109.000, becoming 149.000, rolled is buf[9] = 129.000.
//   150. Input is 149.000. Current sums are 2390.000 // 2790.000.
//   151. buf[30] was 110.000, becoming 150.000, rolled is buf[10] = 130.000.
//   151. Input is 150.000. Current sums are 2410.000 // 2810.000.
//   152. buf[31] was 111.000, becoming 151.000, rolled is buf[11] = 131.000.
//   152. Input is 151.000. Current sums are 2430.000 // 2830.000.
//   153. buf[32] was 112.000, becoming 152.000, rolled is buf[12] = 132.000.
//   153. Input is 152.000. Current sums are 2450.000 // 2850.000.
//   154. buf[33] was 113.000, becoming 153.000, rolled is buf[13] = 133.000.
//   154. Input is 153.000. Current sums are 2470.000 // 2870.000.
//   155. buf[34] was 114.000, becoming 154.000, rolled is buf[14] = 134.000.
//   155. Input is 154.000. Current sums are 2490.000 // 2890.000.
//   156. buf[35] was 115.000, becoming 155.000, rolled is buf[15] = 135.000.
//   156. Input is 155.000. Current sums are 2510.000 // 2910.000.
//   157. buf[36] was 116.000, becoming 156.000, rolled is buf[16] = 136.000.
//   157. Input is 156.000. Current sums are 2530.000 // 2930.000.
//   158. buf[37] was 117.000, becoming 157.000, rolled is buf[17] = 137.000.
//   158. Input is 157.000. Current sums are 2550.000 // 2950.000.
//   159. buf[38] was 118.000, becoming 158.000, rolled is buf[18] = 138.000.
//   159. Input is 158.000. Current sums are 2570.000 // 2970.000.
//   160. buf[39] was 119.000, becoming 159.000, rolled is buf[19] = 139.000.
//   160. Input is 159.000. Current sums are 2590.000 // 2990.000.
// checking averages...
//   161. buf[0] was 120.000, becoming 160.000, rolled is buf[20] = 140.000.
//   161. Input is 160.000. Current sums are 2610.000 // 3010.000.
//   162. buf[1] was 121.000, becoming 161.000, rolled is buf[21] = 141.000.
//   162. Input is 161.000. Current sums are 2630.000 // 3030.000.
//   163. buf[2] was 122.000, becoming 162.000, rolled is buf[22] = 142.000.
//   163. Input is 162.000. Current sums are 2650.000 // 3050.000.
//   164. buf[3] was 123.000, becoming 163.000, rolled is buf[23] = 143.000.
//   164. Input is 163.000. Current sums are 2670.000 // 3070.000.
//   165. buf[4] was 124.000, becoming 164.000, rolled is buf[24] = 144.000.
//   165. Input is 164.000. Current sums are 2690.000 // 3090.000.
//   166. buf[5] was 125.000, becoming 165.000, rolled is buf[25] = 145.000.
//   166. Input is 165.000. Current sums are 2710.000 // 3110.000.
//   167. buf[6] was 126.000, becoming 166.000, rolled is buf[26] = 146.000.
//   167. Input is 166.000. Current sums are 2730.000 // 3130.000.
//   168. buf[7] was 127.000, becoming 167.000, rolled is buf[27] = 147.000.
//   168. Input is 167.000. Current sums are 2750.000 // 3150.000.
//   169. buf[8] was 128.000, becoming 168.000, rolled is buf[28] = 148.000.
//   169. Input is 168.000. Current sums are 2770.000 // 3170.000.
//   170. buf[9] was 129.000, becoming 169.000, rolled is buf[29] = 149.000.
//   170. Input is 169.000. Current sums are 2790.000 // 3190.000.
//   171. buf[10] was 130.000, becoming 170.000, rolled is buf[30] = 150.000.
//   171. Input is 170.000. Current sums are 2810.000 // 3210.000.
//   172. buf[11] was 131.000, becoming 171.000, rolled is buf[31] = 151.000.
//   172. Input is 171.000. Current sums are 2830.000 // 3230.000.
//   173. buf[12] was 132.000, becoming 172.000, rolled is buf[32] = 152.000.
//   173. Input is 172.000. Current sums are 2850.000 // 3250.000.
//   174. buf[13] was 133.000, becoming 173.000, rolled is buf[33] = 153.000.
//   174. Input is 173.000. Current sums are 2870.000 // 3270.000.
//   175. buf[14] was 134.000, becoming 174.000, rolled is buf[34] = 154.000.
//   175. Input is 174.000. Current sums are 2890.000 // 3290.000.
//   176. buf[15] was 135.000, becoming 175.000, rolled is buf[35] = 155.000.
//   176. Input is 175.000. Current sums are 2910.000 // 3310.000.
//   177. buf[16] was 136.000, becoming 176.000, rolled is buf[36] = 156.000.
//   177. Input is 176.000. Current sums are 2930.000 // 3330.000.
//   178. buf[17] was 137.000, becoming 177.000, rolled is buf[37] = 157.000.
//   178. Input is 177.000. Current sums are 2950.000 // 3350.000.
//   179. buf[18] was 138.000, becoming 178.000, rolled is buf[38] = 158.000.
//   179. Input is 178.000. Current sums are 2970.000 // 3370.000.
//   180. buf[19] was 139.000, becoming 179.000, rolled is buf[39] = 159.000.
//   180. Input is 179.000. Current sums are 2990.000 // 3390.000.
// checking averages...
//   181. buf[20] was 140.000, becoming 180.000, rolled is buf[0] = 160.000.
//   181. Input is 180.000. Current sums are 3010.000 // 3410.000.
//   182. buf[21] was 141.000, becoming 181.000, rolled is buf[1] = 161.000.
//   182. Input is 181.000. Current sums are 3030.000 // 3430.000.
//   183. buf[22] was 142.000, becoming 182.000, rolled is buf[2] = 162.000.
//   183. Input is 182.000. Current sums are 3050.000 // 3450.000.
//   184. buf[23] was 143.000, becoming 183.000, rolled is buf[3] = 163.000.
//   184. Input is 183.000. Current sums are 3070.000 // 3470.000.
//   185. buf[24] was 144.000, becoming 184.000, rolled is buf[4] = 164.000.
//   185. Input is 184.000. Current sums are 3090.000 // 3490.000.
//   186. buf[25] was 145.000, becoming 185.000, rolled is buf[5] = 165.000.
//   186. Input is 185.000. Current sums are 3110.000 // 3510.000.
//   187. buf[26] was 146.000, becoming 186.000, rolled is buf[6] = 166.000.
//   187. Input is 186.000. Current sums are 3130.000 // 3530.000.
//   188. buf[27] was 147.000, becoming 187.000, rolled is buf[7] = 167.000.
//   188. Input is 187.000. Current sums are 3150.000 // 3550.000.
//   189. buf[28] was 148.000, becoming 188.000, rolled is buf[8] = 168.000.
//   189. Input is 188.000. Current sums are 3170.000 // 3570.000.
//   190. buf[29] was 149.000, becoming 189.000, rolled is buf[9] = 169.000.
//   190. Input is 189.000. Current sums are 3190.000 // 3590.000.
//   191. buf[30] was 150.000, becoming 190.000, rolled is buf[10] = 170.000.
//   191. Input is 190.000. Current sums are 3210.000 // 3610.000.
//   192. buf[31] was 151.000, becoming 191.000, rolled is buf[11] = 171.000.
//   192. Input is 191.000. Current sums are 3230.000 // 3630.000.
//   193. buf[32] was 152.000, becoming 192.000, rolled is buf[12] = 172.000.
//   193. Input is 192.000. Current sums are 3250.000 // 3650.000.
//   194. buf[33] was 153.000, becoming 193.000, rolled is buf[13] = 173.000.
//   194. Input is 193.000. Current sums are 3270.000 // 3670.000.
//   195. buf[34] was 154.000, becoming 194.000, rolled is buf[14] = 174.000.
//   195. Input is 194.000. Current sums are 3290.000 // 3690.000.
//   196. buf[35] was 155.000, becoming 195.000, rolled is buf[15] = 175.000.
//   196. Input is 195.000. Current sums are 3310.000 // 3710.000.
//   197. buf[36] was 156.000, becoming 196.000, rolled is buf[16] = 176.000.
//   197. Input is 196.000. Current sums are 3330.000 // 3730.000.
//   198. buf[37] was 157.000, becoming 197.000, rolled is buf[17] = 177.000.
//   198. Input is 197.000. Current sums are 3350.000 // 3750.000.
//   199. buf[38] was 158.000, becoming 198.000, rolled is buf[18] = 178.000.
//   199. Input is 198.000. Current sums are 3370.000 // 3770.000.
//   200. buf[39] was 159.000, becoming 199.000, rolled is buf[19] = 179.000.
//   200. Input is 199.000. Current sums are 3390.000 // 3790.000.
// checking averages...
//   201. buf[0] was 160.000, becoming 200.000, rolled is buf[20] = 180.000.
//   201. Input is 200.000. Current sums are 3410.000 // 3810.000.
//   202. buf[1] was 161.000, becoming 201.000, rolled is buf[21] = 181.000.
//   202. Input is 201.000. Current sums are 3430.000 // 3830.000.
//   203. buf[2] was 162.000, becoming 202.000, rolled is buf[22] = 182.000.
//   203. Input is 202.000. Current sums are 3450.000 // 3850.000.
//   204. buf[3] was 163.000, becoming 203.000, rolled is buf[23] = 183.000.
//   204. Input is 203.000. Current sums are 3470.000 // 3870.000.
//   205. buf[4] was 164.000, becoming 204.000, rolled is buf[24] = 184.000.
//   205. Input is 204.000. Current sums are 3490.000 // 3890.000.
//   206. buf[5] was 165.000, becoming 205.000, rolled is buf[25] = 185.000.
//   206. Input is 205.000. Current sums are 3510.000 // 3910.000.
//   207. buf[6] was 166.000, becoming 206.000, rolled is buf[26] = 186.000.
//   207. Input is 206.000. Current sums are 3530.000 // 3930.000.
//   208. buf[7] was 167.000, becoming 207.000, rolled is buf[27] = 187.000.
//   208. Input is 207.000. Current sums are 3550.000 // 3950.000.
//   209. buf[8] was 168.000, becoming 208.000, rolled is buf[28] = 188.000.
//   209. Input is 208.000. Current sums are 3570.000 // 3970.000.
//   210. buf[9] was 169.000, becoming 209.000, rolled is buf[29] = 189.000.
//   210. Input is 209.000. Current sums are 3590.000 // 3990.000.
//   211. buf[10] was 170.000, becoming 210.000, rolled is buf[30] = 190.000.
//   211. Input is 210.000. Current sums are 3610.000 // 4010.000.
//   212. buf[11] was 171.000, becoming 211.000, rolled is buf[31] = 191.000.
//   212. Input is 211.000. Current sums are 3630.000 // 4030.000.
//   213. buf[12] was 172.000, becoming 212.000, rolled is buf[32] = 192.000.
//   213. Input is 212.000. Current sums are 3650.000 // 4050.000.
//   214. buf[13] was 173.000, becoming 213.000, rolled is buf[33] = 193.000.
//   214. Input is 213.000. Current sums are 3670.000 // 4070.000.
//   215. buf[14] was 174.000, becoming 214.000, rolled is buf[34] = 194.000.
//   215. Input is 214.000. Current sums are 3690.000 // 4090.000.
//   216. buf[15] was 175.000, becoming 215.000, rolled is buf[35] = 195.000.
//   216. Input is 215.000. Current sums are 3710.000 // 4110.000.
//   217. buf[16] was 176.000, becoming 216.000, rolled is buf[36] = 196.000.
//   217. Input is 216.000. Current sums are 3730.000 // 4130.000.
//   218. buf[17] was 177.000, becoming 217.000, rolled is buf[37] = 197.000.
//   218. Input is 217.000. Current sums are 3750.000 // 4150.000.
//   219. buf[18] was 178.000, becoming 218.000, rolled is buf[38] = 198.000.
//   219. Input is 218.000. Current sums are 3770.000 // 4170.000.
//   220. buf[19] was 179.000, becoming 219.000, rolled is buf[39] = 199.000.
//   220. Input is 219.000. Current sums are 3790.000 // 4190.000.
// checking averages...
//   221. buf[20] was 180.000, becoming 220.000, rolled is buf[0] = 200.000.
//   221. Input is 220.000. Current sums are 3810.000 // 4210.000.
//   222. buf[21] was 181.000, becoming 221.000, rolled is buf[1] = 201.000.
//   222. Input is 221.000. Current sums are 3830.000 // 4230.000.
//   223. buf[22] was 182.000, becoming 222.000, rolled is buf[2] = 202.000.
//   223. Input is 222.000. Current sums are 3850.000 // 4250.000.
//   224. buf[23] was 183.000, becoming 223.000, rolled is buf[3] = 203.000.
//   224. Input is 223.000. Current sums are 3870.000 // 4270.000.
//   225. buf[24] was 184.000, becoming 224.000, rolled is buf[4] = 204.000.
//   225. Input is 224.000. Current sums are 3890.000 // 4290.000.
//   226. buf[25] was 185.000, becoming 225.000, rolled is buf[5] = 205.000.
//   226. Input is 225.000. Current sums are 3910.000 // 4310.000.
//   227. buf[26] was 186.000, becoming 226.000, rolled is buf[6] = 206.000.
//   227. Input is 226.000. Current sums are 3930.000 // 4330.000.
//   228. buf[27] was 187.000, becoming 227.000, rolled is buf[7] = 207.000.
//   228. Input is 227.000. Current sums are 3950.000 // 4350.000.
//   229. buf[28] was 188.000, becoming 228.000, rolled is buf[8] = 208.000.
//   229. Input is 228.000. Current sums are 3970.000 // 4370.000.
//   230. buf[29] was 189.000, becoming 229.000, rolled is buf[9] = 209.000.
//   230. Input is 229.000. Current sums are 3990.000 // 4390.000.
//   231. buf[30] was 190.000, becoming 230.000, rolled is buf[10] = 210.000.
//   231. Input is 230.000. Current sums are 4010.000 // 4410.000.
//   232. buf[31] was 191.000, becoming 231.000, rolled is buf[11] = 211.000.
//   232. Input is 231.000. Current sums are 4030.000 // 4430.000.
//   233. buf[32] was 192.000, becoming 232.000, rolled is buf[12] = 212.000.
//   233. Input is 232.000. Current sums are 4050.000 // 4450.000.
//   234. buf[33] was 193.000, becoming 233.000, rolled is buf[13] = 213.000.
//   234. Input is 233.000. Current sums are 4070.000 // 4470.000.
//   235. buf[34] was 194.000, becoming 234.000, rolled is buf[14] = 214.000.
//   235. Input is 234.000. Current sums are 4090.000 // 4490.000.
//   236. buf[35] was 195.000, becoming 235.000, rolled is buf[15] = 215.000.
//   236. Input is 235.000. Current sums are 4110.000 // 4510.000.
//   237. buf[36] was 196.000, becoming 236.000, rolled is buf[16] = 216.000.
//   237. Input is 236.000. Current sums are 4130.000 // 4530.000.
//   238. buf[37] was 197.000, becoming 237.000, rolled is buf[17] = 217.000.
//   238. Input is 237.000. Current sums are 4150.000 // 4550.000.
//   239. buf[38] was 198.000, becoming 238.000, rolled is buf[18] = 218.000.
//   239. Input is 238.000. Current sums are 4170.000 // 4570.000.
//   240. buf[39] was 199.000, becoming 239.000, rolled is buf[19] = 219.000.
//   240. Input is 239.000. Current sums are 4190.000 // 4590.000.
// checking averages...
//   241. buf[0] was 200.000, becoming 240.000, rolled is buf[20] = 220.000.
//   241. Input is 240.000. Current sums are 4210.000 // 4610.000.
//   242. buf[1] was 201.000, becoming 241.000, rolled is buf[21] = 221.000.
//   242. Input is 241.000. Current sums are 4230.000 // 4630.000.
//   243. buf[2] was 202.000, becoming 242.000, rolled is buf[22] = 222.000.
//   243. Input is 242.000. Current sums are 4250.000 // 4650.000.
//   244. buf[3] was 203.000, becoming 243.000, rolled is buf[23] = 223.000.
//   244. Input is 243.000. Current sums are 4270.000 // 4670.000.
//   245. buf[4] was 204.000, becoming 244.000, rolled is buf[24] = 224.000.
//   245. Input is 244.000. Current sums are 4290.000 // 4690.000.
//   246. buf[5] was 205.000, becoming 245.000, rolled is buf[25] = 225.000.
//   246. Input is 245.000. Current sums are 4310.000 // 4710.000.
//   247. buf[6] was 206.000, becoming 246.000, rolled is buf[26] = 226.000.
//   247. Input is 246.000. Current sums are 4330.000 // 4730.000.
//   248. buf[7] was 207.000, becoming 247.000, rolled is buf[27] = 227.000.
//   248. Input is 247.000. Current sums are 4350.000 // 4750.000.
//   249. buf[8] was 208.000, becoming 248.000, rolled is buf[28] = 228.000.
//   249. Input is 248.000. Current sums are 4370.000 // 4770.000.
//   250. buf[9] was 209.000, becoming 249.000, rolled is buf[29] = 229.000.
//   250. Input is 249.000. Current sums are 4390.000 // 4790.000.
//   251. buf[10] was 210.000, becoming 250.000, rolled is buf[30] = 230.000.
//   251. Input is 250.000. Current sums are 4410.000 // 4810.000.
//   252. buf[11] was 211.000, becoming 251.000, rolled is buf[31] = 231.000.
//   252. Input is 251.000. Current sums are 4430.000 // 4830.000.
//   253. buf[12] was 212.000, becoming 252.000, rolled is buf[32] = 232.000.
//   253. Input is 252.000. Current sums are 4450.000 // 4850.000.
//   254. buf[13] was 213.000, becoming 253.000, rolled is buf[33] = 233.000.
//   254. Input is 253.000. Current sums are 4470.000 // 4870.000.
//   255. buf[14] was 214.000, becoming 254.000, rolled is buf[34] = 234.000.
//   255. Input is 254.000. Current sums are 4490.000 // 4890.000.
//   256. buf[15] was 215.000, becoming 255.000, rolled is buf[35] = 235.000.
//   256. Input is 255.000. Current sums are 4510.000 // 4910.000.
//   257. buf[16] was 216.000, becoming 256.000, rolled is buf[36] = 236.000.
//   257. Input is 256.000. Current sums are 4530.000 // 4930.000.
//   258. buf[17] was 217.000, becoming 257.000, rolled is buf[37] = 237.000.
//   258. Input is 257.000. Current sums are 4550.000 // 4950.000.
//   259. buf[18] was 218.000, becoming 258.000, rolled is buf[38] = 238.000.
//   259. Input is 258.000. Current sums are 4570.000 // 4970.000.
//   260. buf[19] was 219.000, becoming 259.000, rolled is buf[39] = 239.000.
//   260. Input is 259.000. Current sums are 4590.000 // 4990.000.
// checking averages...
//   261. buf[20] was 220.000, becoming 260.000, rolled is buf[0] = 240.000.
//   261. Input is 260.000. Current sums are 4610.000 // 5010.000.
//   262. buf[21] was 221.000, becoming 261.000, rolled is buf[1] = 241.000.
//   262. Input is 261.000. Current sums are 4630.000 // 5030.000.
//   263. buf[22] was 222.000, becoming 262.000, rolled is buf[2] = 242.000.
//   263. Input is 262.000. Current sums are 4650.000 // 5050.000.
//   264. buf[23] was 223.000, becoming 263.000, rolled is buf[3] = 243.000.
//   264. Input is 263.000. Current sums are 4670.000 // 5070.000.
//   265. buf[24] was 224.000, becoming 264.000, rolled is buf[4] = 244.000.
//   265. Input is 264.000. Current sums are 4690.000 // 5090.000.
//   266. buf[25] was 225.000, becoming 265.000, rolled is buf[5] = 245.000.
//   266. Input is 265.000. Current sums are 4710.000 // 5110.000.
//   267. buf[26] was 226.000, becoming 266.000, rolled is buf[6] = 246.000.
//   267. Input is 266.000. Current sums are 4730.000 // 5130.000.
//   268. buf[27] was 227.000, becoming 267.000, rolled is buf[7] = 247.000.
//   268. Input is 267.000. Current sums are 4750.000 // 5150.000.
//   269. buf[28] was 228.000, becoming 268.000, rolled is buf[8] = 248.000.
//   269. Input is 268.000. Current sums are 4770.000 // 5170.000.
//   270. buf[29] was 229.000, becoming 269.000, rolled is buf[9] = 249.000.
//   270. Input is 269.000. Current sums are 4790.000 // 5190.000.
//   271. buf[30] was 230.000, becoming 270.000, rolled is buf[10] = 250.000.
//   271. Input is 270.000. Current sums are 4810.000 // 5210.000.
//   272. buf[31] was 231.000, becoming 271.000, rolled is buf[11] = 251.000.
//   272. Input is 271.000. Current sums are 4830.000 // 5230.000.
//   273. buf[32] was 232.000, becoming 272.000, rolled is buf[12] = 252.000.
//   273. Input is 272.000. Current sums are 4850.000 // 5250.000.
//   274. buf[33] was 233.000, becoming 273.000, rolled is buf[13] = 253.000.
//   274. Input is 273.000. Current sums are 4870.000 // 5270.000.
//   275. buf[34] was 234.000, becoming 274.000, rolled is buf[14] = 254.000.
//   275. Input is 274.000. Current sums are 4890.000 // 5290.000.
//   276. buf[35] was 235.000, becoming 275.000, rolled is buf[15] = 255.000.
//   276. Input is 275.000. Current sums are 4910.000 // 5310.000.
//   277. buf[36] was 236.000, becoming 276.000, rolled is buf[16] = 256.000.
//   277. Input is 276.000. Current sums are 4930.000 // 5330.000.
//   278. buf[37] was 237.000, becoming 277.000, rolled is buf[17] = 257.000.
//   278. Input is 277.000. Current sums are 4950.000 // 5350.000.
//   279. buf[38] was 238.000, becoming 278.000, rolled is buf[18] = 258.000.
//   279. Input is 278.000. Current sums are 4970.000 // 5370.000.
//   280. buf[39] was 239.000, becoming 279.000, rolled is buf[19] = 259.000.
//   280. Input is 279.000. Current sums are 4990.000 // 5390.000.
// checking averages...
//   281. buf[0] was 240.000, becoming 280.000, rolled is buf[20] = 260.000.
//   281. Input is 280.000. Current sums are 5010.000 // 5410.000.
//   282. buf[1] was 241.000, becoming 281.000, rolled is buf[21] = 261.000.
//   282. Input is 281.000. Current sums are 5030.000 // 5430.000.
//   283. buf[2] was 242.000, becoming 282.000, rolled is buf[22] = 262.000.
//   283. Input is 282.000. Current sums are 5050.000 // 5450.000.
//   284. buf[3] was 243.000, becoming 283.000, rolled is buf[23] = 263.000.
//   284. Input is 283.000. Current sums are 5070.000 // 5470.000.
//   285. buf[4] was 244.000, becoming 284.000, rolled is buf[24] = 264.000.
//   285. Input is 284.000. Current sums are 5090.000 // 5490.000.
//   286. buf[5] was 245.000, becoming 285.000, rolled is buf[25] = 265.000.
//   286. Input is 285.000. Current sums are 5110.000 // 5510.000.
//   287. buf[6] was 246.000, becoming 286.000, rolled is buf[26] = 266.000.
//   287. Input is 286.000. Current sums are 5130.000 // 5530.000.
//   288. buf[7] was 247.000, becoming 287.000, rolled is buf[27] = 267.000.
//   288. Input is 287.000. Current sums are 5150.000 // 5550.000.
//   289. buf[8] was 248.000, becoming 288.000, rolled is buf[28] = 268.000.
//   289. Input is 288.000. Current sums are 5170.000 // 5570.000.
//   290. buf[9] was 249.000, becoming 289.000, rolled is buf[29] = 269.000.
//   290. Input is 289.000. Current sums are 5190.000 // 5590.000.
//   291. buf[10] was 250.000, becoming 290.000, rolled is buf[30] = 270.000.
//   291. Input is 290.000. Current sums are 5210.000 // 5610.000.
//   292. buf[11] was 251.000, becoming 291.000, rolled is buf[31] = 271.000.
//   292. Input is 291.000. Current sums are 5230.000 // 5630.000.
//   293. buf[12] was 252.000, becoming 292.000, rolled is buf[32] = 272.000.
//   293. Input is 292.000. Current sums are 5250.000 // 5650.000.
//   294. buf[13] was 253.000, becoming 293.000, rolled is buf[33] = 273.000.
//   294. Input is 293.000. Current sums are 5270.000 // 5670.000.
//   295. buf[14] was 254.000, becoming 294.000, rolled is buf[34] = 274.000.
//   295. Input is 294.000. Current sums are 5290.000 // 5690.000.
//   296. buf[15] was 255.000, becoming 295.000, rolled is buf[35] = 275.000.
//   296. Input is 295.000. Current sums are 5310.000 // 5710.000.
//   297. buf[16] was 256.000, becoming 296.000, rolled is buf[36] = 276.000.
//   297. Input is 296.000. Current sums are 5330.000 // 5730.000.
//   298. buf[17] was 257.000, becoming 297.000, rolled is buf[37] = 277.000.
//   298. Input is 297.000. Current sums are 5350.000 // 5750.000.
//   299. buf[18] was 258.000, becoming 298.000, rolled is buf[38] = 278.000.
//   299. Input is 298.000. Current sums are 5370.000 // 5770.000.
//   300. buf[19] was 259.000, becoming 299.000, rolled is buf[39] = 279.000.
//   300. Input is 299.000. Current sums are 5390.000 // 5790.000.
// checking averages...
//   301. buf[20] was 260.000, becoming 300.000, rolled is buf[0] = 280.000.
//   301. Input is 300.000. Current sums are 5410.000 // 5810.000.
//   302. buf[21] was 261.000, becoming 301.000, rolled is buf[1] = 281.000.
//   302. Input is 301.000. Current sums are 5430.000 // 5830.000.
//   303. buf[22] was 262.000, becoming 302.000, rolled is buf[2] = 282.000.
//   303. Input is 302.000. Current sums are 5450.000 // 5850.000.
//   304. buf[23] was 263.000, becoming 303.000, rolled is buf[3] = 283.000.
//   304. Input is 303.000. Current sums are 5470.000 // 5870.000.
//   305. buf[24] was 264.000, becoming 304.000, rolled is buf[4] = 284.000.
//   305. Input is 304.000. Current sums are 5490.000 // 5890.000.
//   306. buf[25] was 265.000, becoming 305.000, rolled is buf[5] = 285.000.
//   306. Input is 305.000. Current sums are 5510.000 // 5910.000.
//   307. buf[26] was 266.000, becoming 306.000, rolled is buf[6] = 286.000.
//   307. Input is 306.000. Current sums are 5530.000 // 5930.000.
//   308. buf[27] was 267.000, becoming 307.000, rolled is buf[7] = 287.000.
//   308. Input is 307.000. Current sums are 5550.000 // 5950.000.
//   309. buf[28] was 268.000, becoming 308.000, rolled is buf[8] = 288.000.
//   309. Input is 308.000. Current sums are 5570.000 // 5970.000.
//   310. buf[29] was 269.000, becoming 309.000, rolled is buf[9] = 289.000.
//   310. Input is 309.000. Current sums are 5590.000 // 5990.000.
//   311. buf[30] was 270.000, becoming 310.000, rolled is buf[10] = 290.000.
//   311. Input is 310.000. Current sums are 5610.000 // 6010.000.
//   312. buf[31] was 271.000, becoming 311.000, rolled is buf[11] = 291.000.
//   312. Input is 311.000. Current sums are 5630.000 // 6030.000.
//   313. buf[32] was 272.000, becoming 312.000, rolled is buf[12] = 292.000.
//   313. Input is 312.000. Current sums are 5650.000 // 6050.000.
//   314. buf[33] was 273.000, becoming 313.000, rolled is buf[13] = 293.000.
//   314. Input is 313.000. Current sums are 5670.000 // 6070.000.
//   315. buf[34] was 274.000, becoming 314.000, rolled is buf[14] = 294.000.
//   315. Input is 314.000. Current sums are 5690.000 // 6090.000.
//   316. buf[35] was 275.000, becoming 315.000, rolled is buf[15] = 295.000.
//   316. Input is 315.000. Current sums are 5710.000 // 6110.000.
//   317. buf[36] was 276.000, becoming 316.000, rolled is buf[16] = 296.000.
//   317. Input is 316.000. Current sums are 5730.000 // 6130.000.
//   318. buf[37] was 277.000, becoming 317.000, rolled is buf[17] = 297.000.
//   318. Input is 317.000. Current sums are 5750.000 // 6150.000.
//   319. buf[38] was 278.000, becoming 318.000, rolled is buf[18] = 298.000.
//   319. Input is 318.000. Current sums are 5770.000 // 6170.000.
//   320. buf[39] was 279.000, becoming 319.000, rolled is buf[19] = 299.000.
//   320. Input is 319.000. Current sums are 5790.000 // 6190.000.
// checking averages...
//   321. buf[0] was 280.000, becoming 320.000, rolled is buf[20] = 300.000.
//   321. Input is 320.000. Current sums are 5810.000 // 6210.000.
//   322. buf[1] was 281.000, becoming 321.000, rolled is buf[21] = 301.000.
//   322. Input is 321.000. Current sums are 5830.000 // 6230.000.
//   323. buf[2] was 282.000, becoming 322.000, rolled is buf[22] = 302.000.
//   323. Input is 322.000. Current sums are 5850.000 // 6250.000.
//   324. buf[3] was 283.000, becoming 323.000, rolled is buf[23] = 303.000.
//   324. Input is 323.000. Current sums are 5870.000 // 6270.000.
//   325. buf[4] was 284.000, becoming 324.000, rolled is buf[24] = 304.000.
//   325. Input is 324.000. Current sums are 5890.000 // 6290.000.
//   326. buf[5] was 285.000, becoming 325.000, rolled is buf[25] = 305.000.
//   326. Input is 325.000. Current sums are 5910.000 // 6310.000.
//   327. buf[6] was 286.000, becoming 326.000, rolled is buf[26] = 306.000.
//   327. Input is 326.000. Current sums are 5930.000 // 6330.000.
//   328. buf[7] was 287.000, becoming 327.000, rolled is buf[27] = 307.000.
//   328. Input is 327.000. Current sums are 5950.000 // 6350.000.
//   329. buf[8] was 288.000, becoming 328.000, rolled is buf[28] = 308.000.
//   329. Input is 328.000. Current sums are 5970.000 // 6370.000.
//   330. buf[9] was 289.000, becoming 329.000, rolled is buf[29] = 309.000.
//   330. Input is 329.000. Current sums are 5990.000 // 6390.000.
//   331. buf[10] was 290.000, becoming 330.000, rolled is buf[30] = 310.000.
//   331. Input is 330.000. Current sums are 6010.000 // 6410.000.
//   332. buf[11] was 291.000, becoming 331.000, rolled is buf[31] = 311.000.
//   332. Input is 331.000. Current sums are 6030.000 // 6430.000.
//   333. buf[12] was 292.000, becoming 332.000, rolled is buf[32] = 312.000.
//   333. Input is 332.000. Current sums are 6050.000 // 6450.000.
//   334. buf[13] was 293.000, becoming 333.000, rolled is buf[33] = 313.000.
//   334. Input is 333.000. Current sums are 6070.000 // 6470.000.
//   335. buf[14] was 294.000, becoming 334.000, rolled is buf[34] = 314.000.
//   335. Input is 334.000. Current sums are 6090.000 // 6490.000.
//   336. buf[15] was 295.000, becoming 335.000, rolled is buf[35] = 315.000.
//   336. Input is 335.000. Current sums are 6110.000 // 6510.000.
//   337. buf[16] was 296.000, becoming 336.000, rolled is buf[36] = 316.000.
//   337. Input is 336.000. Current sums are 6130.000 // 6530.000.
//   338. buf[17] was 297.000, becoming 337.000, rolled is buf[37] = 317.000.
//   338. Input is 337.000. Current sums are 6150.000 // 6550.000.
//   339. buf[18] was 298.000, becoming 338.000, rolled is buf[38] = 318.000.
//   339. Input is 338.000. Current sums are 6170.000 // 6570.000.
//   340. buf[19] was 299.000, becoming 339.000, rolled is buf[39] = 319.000.
//   340. Input is 339.000. Current sums are 6190.000 // 6590.000.
// checking averages...
//   341. buf[20] was 300.000, becoming 340.000, rolled is buf[0] = 320.000.
//   341. Input is 340.000. Current sums are 6210.000 // 6610.000.
//   342. buf[21] was 301.000, becoming 341.000, rolled is buf[1] = 321.000.
//   342. Input is 341.000. Current sums are 6230.000 // 6630.000.
//   343. buf[22] was 302.000, becoming 342.000, rolled is buf[2] = 322.000.
//   343. Input is 342.000. Current sums are 6250.000 // 6650.000.
//   344. buf[23] was 303.000, becoming 343.000, rolled is buf[3] = 323.000.
//   344. Input is 343.000. Current sums are 6270.000 // 6670.000.
//   345. buf[24] was 304.000, becoming 344.000, rolled is buf[4] = 324.000.
//   345. Input is 344.000. Current sums are 6290.000 // 6690.000.
//   346. buf[25] was 305.000, becoming 345.000, rolled is buf[5] = 325.000.
//   346. Input is 345.000. Current sums are 6310.000 // 6710.000.
//   347. buf[26] was 306.000, becoming 346.000, rolled is buf[6] = 326.000.
//   347. Input is 346.000. Current sums are 6330.000 // 6730.000.
// ...
//   873. Input is 872.000. Current sums are 16850.000 // 17250.000.
//   874. buf[33] was 833.000, becoming 873.000, rolled is buf[13] = 853.000.
//   874. Input is 873.000. Current sums are 16870.000 // 17270.000.
//   875. buf[34] was 834.000, becoming 874.000, rolled is buf[14] = 854.000.
//   875. Input is 874.000. Current sums are 16890.000 // 17290.000.
//   876. buf[35] was 835.000, becoming 875.000, rolled is buf[15] = 855.000.
//   876. Input is 875.000. Current sums are 16910.000 // 17310.000.
//   877. buf[36] was 836.000, becoming 876.000, rolled is buf[16] = 856.000.
//   877. Input is 876.000. Current sums are 16930.000 // 17330.000.
//   878. buf[37] was 837.000, becoming 877.000, rolled is buf[17] = 857.000.
//   878. Input is 877.000. Current sums are 16950.000 // 17350.000.
//   879. buf[38] was 838.000, becoming 878.000, rolled is buf[18] = 858.000.
//   879. Input is 878.000. Current sums are 16970.000 // 17370.000.
//   880. buf[39] was 839.000, becoming 879.000, rolled is buf[19] = 859.000.
//   880. Input is 879.000. Current sums are 16990.000 // 17390.000.
// checking averages...
//   881. buf[0] was 840.000, becoming 880.000, rolled is buf[20] = 860.000.
//   881. Input is 880.000. Current sums are 17010.000 // 17410.000.
//   882. buf[1] was 841.000, becoming 881.000, rolled is buf[21] = 861.000.
//   882. Input is 881.000. Current sums are 17030.000 // 17430.000.
//   883. buf[2] was 842.000, becoming 882.000, rolled is buf[22] = 862.000.
//   883. Input is 882.000. Current sums are 17050.000 // 17450.000.
//   884. buf[3] was 843.000, becoming 883.000, rolled is buf[23] = 863.000.
//   884. Input is 883.000. Current sums are 17070.000 // 17470.000.
//   885. buf[4] was 844.000, becoming 884.000, rolled is buf[24] = 864.000.
//   885. Input is 884.000. Current sums are 17090.000 // 17490.000.
//   886. buf[5] was 845.000, becoming 885.000, rolled is buf[25] = 865.000.
//   886. Input is 885.000. Current sums are 17110.000 // 17510.000.
//   887. buf[6] was 846.000, becoming 886.000, rolled is buf[26] = 866.000.
//   887. Input is 886.000. Current sums are 17130.000 // 17530.000.
//   888. buf[7] was 847.000, becoming 887.000, rolled is buf[27] = 867.000.
//   888. Input is 887.000. Current sums are 17150.000 // 17550.000.
//   889. buf[8] was 848.000, becoming 888.000, rolled is buf[28] = 868.000.
//   889. Input is 888.000. Current sums are 17170.000 // 17570.000.
//   890. buf[9] was 849.000, becoming 889.000, rolled is buf[29] = 869.000.
//   890. Input is 889.000. Current sums are 17190.000 // 17590.000.
//   891. buf[10] was 850.000, becoming 890.000, rolled is buf[30] = 870.000.
//   891. Input is 890.000. Current sums are 17210.000 // 17610.000.
//   892. buf[11] was 851.000, becoming 891.000, rolled is buf[31] = 871.000.
//   892. Input is 891.000. Current sums are 17230.000 // 17630.000.
//   893. buf[12] was 852.000, becoming 892.000, rolled is buf[32] = 872.000.
//   893. Input is 892.000. Current sums are 17250.000 // 17650.000.
//   894. buf[13] was 853.000, becoming 893.000, rolled is buf[33] = 873.000.
//   894. Input is 893.000. Current sums are 17270.000 // 17670.000.
//   895. buf[14] was 854.000, becoming 894.000, rolled is buf[34] = 874.000.
//   895. Input is 894.000. Current sums are 17290.000 // 17690.000.
//   896. buf[15] was 855.000, becoming 895.000, rolled is buf[35] = 875.000.
//   896. Input is 895.000. Current sums are 17310.000 // 17710.000.
//   897. buf[16] was 856.000, becoming 896.000, rolled is buf[36] = 876.000.
//   897. Input is 896.000. Current sums are 17330.000 // 17730.000.
//   898. buf[17] was 857.000, becoming 897.000, rolled is buf[37] = 877.000.
//   898. Input is 897.000. Current sums are 17350.000 // 17750.000.
//   899. buf[18] was 858.000, becoming 898.000, rolled is buf[38] = 878.000.
//   899. Input is 898.000. Current sums are 17370.000 // 17770.000.
//   900. buf[19] was 859.000, becoming 899.000, rolled is buf[39] = 879.000.
//   900. Input is 899.000. Current sums are 17390.000 // 17790.000.
// checking averages...
//   901. buf[20] was 860.000, becoming 900.000, rolled is buf[0] = 880.000.
//   901. Input is 900.000. Current sums are 17410.000 // 17810.000.
//   902. buf[21] was 861.000, becoming 901.000, rolled is buf[1] = 881.000.
//   902. Input is 901.000. Current sums are 17430.000 // 17830.000.
//   903. buf[22] was 862.000, becoming 902.000, rolled is buf[2] = 882.000.
//   903. Input is 902.000. Current sums are 17450.000 // 17850.000.
//   904. buf[23] was 863.000, becoming 903.000, rolled is buf[3] = 883.000.
//   904. Input is 903.000. Current sums are 17470.000 // 17870.000.
//   905. buf[24] was 864.000, becoming 904.000, rolled is buf[4] = 884.000.
//   905. Input is 904.000. Current sums are 17490.000 // 17890.000.
//   906. buf[25] was 865.000, becoming 905.000, rolled is buf[5] = 885.000.
//   906. Input is 905.000. Current sums are 17510.000 // 17910.000.
//   907. buf[26] was 866.000, becoming 906.000, rolled is buf[6] = 886.000.
//   907. Input is 906.000. Current sums are 17530.000 // 17930.000.
//   908. buf[27] was 867.000, becoming 907.000, rolled is buf[7] = 887.000.
//   908. Input is 907.000. Current sums are 17550.000 // 17950.000.
//   909. buf[28] was 868.000, becoming 908.000, rolled is buf[8] = 888.000.
//   909. Input is 908.000. Current sums are 17570.000 // 17970.000.
//   910. buf[29] was 869.000, becoming 909.000, rolled is buf[9] = 889.000.
//   910. Input is 909.000. Current sums are 17590.000 // 17990.000.
//   911. buf[30] was 870.000, becoming 910.000, rolled is buf[10] = 890.000.
//   911. Input is 910.000. Current sums are 17610.000 // 18010.000.
//   912. buf[31] was 871.000, becoming 911.000, rolled is buf[11] = 891.000.
//   912. Input is 911.000. Current sums are 17630.000 // 18030.000.
//   913. buf[32] was 872.000, becoming 912.000, rolled is buf[12] = 892.000.
//   913. Input is 912.000. Current sums are 17650.000 // 18050.000.
//   914. buf[33] was 873.000, becoming 913.000, rolled is buf[13] = 893.000.
//   914. Input is 913.000. Current sums are 17670.000 // 18070.000.
//   915. buf[34] was 874.000, becoming 914.000, rolled is buf[14] = 894.000.
//   915. Input is 914.000. Current sums are 17690.000 // 18090.000.
//   916. buf[35] was 875.000, becoming 915.000, rolled is buf[15] = 895.000.
//   916. Input is 915.000. Current sums are 17710.000 // 18110.000.
//   917. buf[36] was 876.000, becoming 916.000, rolled is buf[16] = 896.000.
//   917. Input is 916.000. Current sums are 17730.000 // 18130.000.
//   918. buf[37] was 877.000, becoming 917.000, rolled is buf[17] = 897.000.
//   918. Input is 917.000. Current sums are 17750.000 // 18150.000.
//   919. buf[38] was 878.000, becoming 918.000, rolled is buf[18] = 898.000.
//   919. Input is 918.000. Current sums are 17770.000 // 18170.000.
//   920. buf[39] was 879.000, becoming 919.000, rolled is buf[19] = 899.000.
//   920. Input is 919.000. Current sums are 17790.000 // 18190.000.
// checking averages...
//   921. buf[0] was 880.000, becoming 920.000, rolled is buf[20] = 900.000.
//   921. Input is 920.000. Current sums are 17810.000 // 18210.000.
//   922. buf[1] was 881.000, becoming 921.000, rolled is buf[21] = 901.000.
//   922. Input is 921.000. Current sums are 17830.000 // 18230.000.
//   923. buf[2] was 882.000, becoming 922.000, rolled is buf[22] = 902.000.
//   923. Input is 922.000. Current sums are 17850.000 // 18250.000.
//   924. buf[3] was 883.000, becoming 923.000, rolled is buf[23] = 903.000.
//   924. Input is 923.000. Current sums are 17870.000 // 18270.000.
//   925. buf[4] was 884.000, becoming 924.000, rolled is buf[24] = 904.000.
//   925. Input is 924.000. Current sums are 17890.000 // 18290.000.
//   926. buf[5] was 885.000, becoming 925.000, rolled is buf[25] = 905.000.
//   926. Input is 925.000. Current sums are 17910.000 // 18310.000.
//   927. buf[6] was 886.000, becoming 926.000, rolled is buf[26] = 906.000.
//   927. Input is 926.000. Current sums are 17930.000 // 18330.000.
//   928. buf[7] was 887.000, becoming 927.000, rolled is buf[27] = 907.000.
//   928. Input is 927.000. Current sums are 17950.000 // 18350.000.
//   929. buf[8] was 888.000, becoming 928.000, rolled is buf[28] = 908.000.
//   929. Input is 928.000. Current sums are 17970.000 // 18370.000.
//   930. buf[9] was 889.000, becoming 929.000, rolled is buf[29] = 909.000.
//   930. Input is 929.000. Current sums are 17990.000 // 18390.000.
//   931. buf[10] was 890.000, becoming 930.000, rolled is buf[30] = 910.000.
//   931. Input is 930.000. Current sums are 18010.000 // 18410.000.
//   932. buf[11] was 891.000, becoming 931.000, rolled is buf[31] = 911.000.
//   932. Input is 931.000. Current sums are 18030.000 // 18430.000.
//   933. buf[12] was 892.000, becoming 932.000, rolled is buf[32] = 912.000.
//   933. Input is 932.000. Current sums are 18050.000 // 18450.000.
//   934. buf[13] was 893.000, becoming 933.000, rolled is buf[33] = 913.000.
//   934. Input is 933.000. Current sums are 18070.000 // 18470.000.
//   935. buf[14] was 894.000, becoming 934.000, rolled is buf[34] = 914.000.
//   935. Input is 934.000. Current sums are 18090.000 // 18490.000.
//   936. buf[15] was 895.000, becoming 935.000, rolled is buf[35] = 915.000.
//   936. Input is 935.000. Current sums are 18110.000 // 18510.000.
//   937. buf[16] was 896.000, becoming 936.000, rolled is buf[36] = 916.000.
//   937. Input is 936.000. Current sums are 18130.000 // 18530.000.
//   938. buf[17] was 897.000, becoming 937.000, rolled is buf[37] = 917.000.
//   938. Input is 937.000. Current sums are 18150.000 // 18550.000.
//   939. buf[18] was 898.000, becoming 938.000, rolled is buf[38] = 918.000.
//   939. Input is 938.000. Current sums are 18170.000 // 18570.000.
//   940. buf[19] was 899.000, becoming 939.000, rolled is buf[39] = 919.000.
//   940. Input is 939.000. Current sums are 18190.000 // 18590.000.
// checking averages...
//   941. buf[20] was 900.000, becoming 940.000, rolled is buf[0] = 920.000.
//   941. Input is 940.000. Current sums are 18210.000 // 18610.000.
//   942. buf[21] was 901.000, becoming 941.000, rolled is buf[1] = 921.000.
//   942. Input is 941.000. Current sums are 18230.000 // 18630.000.
//   943. buf[22] was 902.000, becoming 942.000, rolled is buf[2] = 922.000.
//   943. Input is 942.000. Current sums are 18250.000 // 18650.000.
//   944. buf[23] was 903.000, becoming 943.000, rolled is buf[3] = 923.000.
//   944. Input is 943.000. Current sums are 18270.000 // 18670.000.
//   945. buf[24] was 904.000, becoming 944.000, rolled is buf[4] = 924.000.
//   945. Input is 944.000. Current sums are 18290.000 // 18690.000.
//   946. buf[25] was 905.000, becoming 945.000, rolled is buf[5] = 925.000.
//   946. Input is 945.000. Current sums are 18310.000 // 18710.000.
//   947. buf[26] was 906.000, becoming 946.000, rolled is buf[6] = 926.000.
//   947. Input is 946.000. Current sums are 18330.000 // 18730.000.
//   948. buf[27] was 907.000, becoming 947.000, rolled is buf[7] = 927.000.
//   948. Input is 947.000. Current sums are 18350.000 // 18750.000.
//   949. buf[28] was 908.000, becoming 948.000, rolled is buf[8] = 928.000.
//   949. Input is 948.000. Current sums are 18370.000 // 18770.000.
//   950. buf[29] was 909.000, becoming 949.000, rolled is buf[9] = 929.000.
//   950. Input is 949.000. Current sums are 18390.000 // 18790.000.
//   951. buf[30] was 910.000, becoming 950.000, rolled is buf[10] = 930.000.
//   951. Input is 950.000. Current sums are 18410.000 // 18810.000.
//   952. buf[31] was 911.000, becoming 951.000, rolled is buf[11] = 931.000.
//   952. Input is 951.000. Current sums are 18430.000 // 18830.000.
//   953. buf[32] was 912.000, becoming 952.000, rolled is buf[12] = 932.000.
//   953. Input is 952.000. Current sums are 18450.000 // 18850.000.
//   954. buf[33] was 913.000, becoming 953.000, rolled is buf[13] = 933.000.
//   954. Input is 953.000. Current sums are 18470.000 // 18870.000.
//   955. buf[34] was 914.000, becoming 954.000, rolled is buf[14] = 934.000.
//   955. Input is 954.000. Current sums are 18490.000 // 18890.000.
//   956. buf[35] was 915.000, becoming 955.000, rolled is buf[15] = 935.000.
//   956. Input is 955.000. Current sums are 18510.000 // 18910.000.
//   957. buf[36] was 916.000, becoming 956.000, rolled is buf[16] = 936.000.
//   957. Input is 956.000. Current sums are 18530.000 // 18930.000.
//   958. buf[37] was 917.000, becoming 957.000, rolled is buf[17] = 937.000.
//   958. Input is 957.000. Current sums are 18550.000 // 18950.000.
//   959. buf[38] was 918.000, becoming 958.000, rolled is buf[18] = 938.000.
//   959. Input is 958.000. Current sums are 18570.000 // 18970.000.
//   960. buf[39] was 919.000, becoming 959.000, rolled is buf[19] = 939.000.
//   960. Input is 959.000. Current sums are 18590.000 // 18990.000.
// checking averages...
//   961. buf[0] was 920.000, becoming 960.000, rolled is buf[20] = 940.000.
//   961. Input is 960.000. Current sums are 18610.000 // 19010.000.
//   962. buf[1] was 921.000, becoming 961.000, rolled is buf[21] = 941.000.
//   962. Input is 961.000. Current sums are 18630.000 // 19030.000.
//   963. buf[2] was 922.000, becoming 962.000, rolled is buf[22] = 942.000.
//   963. Input is 962.000. Current sums are 18650.000 // 19050.000.
//   964. buf[3] was 923.000, becoming 963.000, rolled is buf[23] = 943.000.
//   964. Input is 963.000. Current sums are 18670.000 // 19070.000.
//   965. buf[4] was 924.000, becoming 964.000, rolled is buf[24] = 944.000.
//   965. Input is 964.000. Current sums are 18690.000 // 19090.000.
//   966. buf[5] was 925.000, becoming 965.000, rolled is buf[25] = 945.000.
//   966. Input is 965.000. Current sums are 18710.000 // 19110.000.
//   967. buf[6] was 926.000, becoming 966.000, rolled is buf[26] = 946.000.
//   967. Input is 966.000. Current sums are 18730.000 // 19130.000.
//   968. buf[7] was 927.000, becoming 967.000, rolled is buf[27] = 947.000.
//   968. Input is 967.000. Current sums are 18750.000 // 19150.000.
//   969. buf[8] was 928.000, becoming 968.000, rolled is buf[28] = 948.000.
//   969. Input is 968.000. Current sums are 18770.000 // 19170.000.
//   970. buf[9] was 929.000, becoming 969.000, rolled is buf[29] = 949.000.
//   970. Input is 969.000. Current sums are 18790.000 // 19190.000.
//   971. buf[10] was 930.000, becoming 970.000, rolled is buf[30] = 950.000.
//   971. Input is 970.000. Current sums are 18810.000 // 19210.000.
//   972. buf[11] was 931.000, becoming 971.000, rolled is buf[31] = 951.000.
//   972. Input is 971.000. Current sums are 18830.000 // 19230.000.
//   973. buf[12] was 932.000, becoming 972.000, rolled is buf[32] = 952.000.
//   973. Input is 972.000. Current sums are 18850.000 // 19250.000.
//   974. buf[13] was 933.000, becoming 973.000, rolled is buf[33] = 953.000.
//   974. Input is 973.000. Current sums are 18870.000 // 19270.000.
//   975. buf[14] was 934.000, becoming 974.000, rolled is buf[34] = 954.000.
//   975. Input is 974.000. Current sums are 18890.000 // 19290.000.
//   976. buf[15] was 935.000, becoming 975.000, rolled is buf[35] = 955.000.
//   976. Input is 975.000. Current sums are 18910.000 // 19310.000.
//   977. buf[16] was 936.000, becoming 976.000, rolled is buf[36] = 956.000.
//   977. Input is 976.000. Current sums are 18930.000 // 19330.000.
//   978. buf[17] was 937.000, becoming 977.000, rolled is buf[37] = 957.000.
//   978. Input is 977.000. Current sums are 18950.000 // 19350.000.
//   979. buf[18] was 938.000, becoming 978.000, rolled is buf[38] = 958.000.
//   979. Input is 978.000. Current sums are 18970.000 // 19370.000.
//   980. buf[19] was 939.000, becoming 979.000, rolled is buf[39] = 959.000.
//   980. Input is 979.000. Current sums are 18990.000 // 19390.000.
// checking averages...
//   981. buf[20] was 940.000, becoming 980.000, rolled is buf[0] = 960.000.
//   981. Input is 980.000. Current sums are 19010.000 // 19410.000.
//   982. buf[21] was 941.000, becoming 981.000, rolled is buf[1] = 961.000.
//   982. Input is 981.000. Current sums are 19030.000 // 19430.000.
//   983. buf[22] was 942.000, becoming 982.000, rolled is buf[2] = 962.000.
//   983. Input is 982.000. Current sums are 19050.000 // 19450.000.
//   984. buf[23] was 943.000, becoming 983.000, rolled is buf[3] = 963.000.
//   984. Input is 983.000. Current sums are 19070.000 // 19470.000.
//   985. buf[24] was 944.000, becoming 984.000, rolled is buf[4] = 964.000.
